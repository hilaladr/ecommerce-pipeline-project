# %%
import pandas as pd
import os
from pathlib import Path

# %%
DOWNLOAD_PATH = ''

# %%
for item in Path(DOWNLOAD_PATH).iterdir() :
    print(item)
# Out:
# kaggle.json
# explore.ipynb
# guide.md
# guide_pseudo.md
# hilaladr-iam_accessKeys.csv
# connections.toml
# snowflake.py
# kaggle api.txt
# config.toml
# ingest.py
# C:\Users\817932594\OneDrive - Kemenkeu\App Development\ecommerce-pipeline-project
# .git

# %%
for item in Path('./temp_data').iterdir() :
    print(os.path.getsize(item) / (1024**2))

# %%
df = pd.read_csv('temp_data/olist_customers_dataset.csv', nrows=20)

# %%
for col in df.columns :
    print(f'{col} type : {df[col].dtype}')
# Out:
# customer_id type : object
# customer_unique_id type : object
# customer_zip_code_prefix type : int64
# customer_city type : object
# customer_state type : object
